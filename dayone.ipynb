# %%
print("hello world")
# Out:
# hello world

# %%
my_var = 10+12j;
#defining a complex number;
print(type(my_var));
# Out:
# <class 'complex'>

# %%
#scientific notation

my_var = 4.85e5;
print(type(my_var));
print(my_var);
# Out:
# <class 'float'>
# 485000.0

# %%
my_var = 10;
my_var2 = float(my_var);
print(my_var,my_var2);
# Out:
# 10 10.0

# %%
my_var = 7.3;
my_var2 = int(my_var);
print(my_var2);
# Out:
# 7

# %%
my_list = [5,3,2,1];
print(my_list);
print(type(my_list));
print(my_list[2]);
my_list.append(5);
print(my_list[4]);
# Out:
# [5, 3, 2, 1]
# <class 'list'>
# 2
# 5
